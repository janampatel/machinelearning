# %%
#code for permanent installation of libraries on colab
import os, sys
from google.colab import drive
drive.mount('/content/drive')
nb_path = '/content/notebooks'
os.symlink('/content/drive/My Drive/ML Lab', nb_path)
sys.path.insert(0,nb_path)
# Out:
# Mounted at /content/drive

# %%
#--target=$nb_path installs at the target path
# !pip install --target=$nb_path tabula-py

#error installing some of the modules of tabula
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 25.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 53.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 66.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 21.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 38.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 27.9 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.0.3 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.25.1 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.25.1 which is incompatible.
# ...

# %%
import tabula
df=tabula.read_pdf("/content/drive/My Drive/ML Lab/report.pdf",pages=3)
print(df[0].shape)
# Out:
# (42, 7)

# %%
import pandas as pd
df=pd.DataFrame(df[0])
df.to_csv("read_table.csv")
df
# Out:
#    At June 30, 2021 and 2020 (In Thousands of Unnamed: 0  Unnamed: 1  \
# 0                                         NaN        NaN         NaN
# 1                                    Dollars)        NaN         NaN
# 2                                         NaN        NaN        2021
# 3                                      ASSETS        NaN         NaN
# 4                   Cash and cash equivalents          $    6 73,528
# 5                    Accounts receivable, net        NaN     286,139
# 6                     Pledges receivable, net        NaN       9,610
# 7         Notes and mortgages receivable, net        NaN       4,636
# 8                                 Inventories        NaN       5,184
# 9                        Other current assets        NaN       7,244
# 10                             Current assets        NaN     986,341
# 11                                Investments        NaN   5,260,459
# 12               Investments held by trustees        NaN     1 0,765
# ...

# %%
#Check if tkinter is available
import tkinter

# %%
# !apt-get install python-tk
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpython2-stdlib libpython2.7-minimal libpython2.7-stdlib python2
#   python2-minimal python2.7 python2.7-minimal
# Suggested packages:
#   tix python-tk-dbg python2-doc python2.7-doc binfmt-support
# The following NEW packages will be installed:
#   libpython2-stdlib libpython2.7-minimal libpython2.7-stdlib python-tk python2
#   python2-minimal python2.7 python2.7-minimal
# 0 upgraded, 8 newly installed, 0 to remove and 8 not upgraded.
# Need to get 4,030 kB of archives.
# After this operation, 16.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libpython2.7-minimal amd64 2.7.18-13ubuntu1.1 [347 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python2.7-minimal amd64 2.7.18-13ubuntu1.1 [1,394 kB]
# ...

# %%
# !pip install tkinter
# !python -m pip install tk
# Out:
# ERROR: Could not find a version that satisfies the requirement tkinter (from versions: none)
# ERROR: No matching distribution found for tkinter
# ...

# %%
# !pip install ghostscript
# !pip install camelot-py[cv]
# !pip install excalibur-py
# !pip install ghostscript python3-tk
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement python3-tk (from versions: none)
# ERROR: No matching distribution found for python3-tk

# %%
# !pip install PyPDF2==1.26.0
import camelot
tables=camelot.read_pdf("/content/drive/My Drive/ML Lab/report.pdf")
print(tables[0])

#due to versions mismatch, this task cant be performed using camelot
#we can use tesseract for ocr and then pandas for conversion to a dataframe
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.6/77.6 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61081 sha256=9d9deac6d0154a49af13aeb97884da4a3625ac25e278ed46791a18e9e1203e91
#   Stored in directory: /root/.cache/pip/wheels/3a/62/ec/b6dea0b680005e9a961a3b195adb5f550b9586e92d20aed01d
# Successfully built PyPDF2
# ...
#   Attempting uninstall: PyPDF2
#     Found existing installation: PyPDF2 3.0.1
#     Uninstalling PyPDF2-3.0.1:
#       Successfully uninstalled PyPDF2-3.0.1
# ...
# ---------------------------------------------------------------------------
# DeprecationError                          Traceback (most recent call last)
# <ipython-input-34-3969e8e4abc4> in <cell line: 3>()
#       1 get_ipython().system('pip install PyPDF2==1.26.0')
#       2 import camelot
# ----> 3 tables=camelot.read_pdf("/content/drive/My Drive/ML Lab/report.pdf")
#       4 print(tables[0])
#
# ...
