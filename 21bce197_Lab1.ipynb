# %%
# installing tessaract ocr environment
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.

# %%
# putesseract is wrapper library for tesseact ocr which helps in reading textual data in images
# !pip install pytesseract

# %%
import pytesseract
import shutil
import os
import random
try:
  from PIL import Image
except ImportError:
  import Image
from google.colab.patches import cv2_imshow
import cv2
from matplotlib import pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8ebe2313-2f37-4c85-8ae5-2e49d420107a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8ebe2313-2f37-4c85-8ae5-2e49d420107a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# read image through cv2 and text conversion
img_read = cv2.imread('Driving License.jpg')
img1 = Image.open('Driving License.jpg')
cv2_imshow(img_read)
plt.imshow(img1)
ocrinfo = pytesseract.image_to_string(img_read)
print(ocrinfo)
# Out:
# <PIL.Image.Image image mode=RGB size=989x1600 at 0x7A9B41197EB0>
#
#
# NAME
# License No.
#
# Authorization
# to Drive
#
# Date of Issue
# DOB
# S/w/D
#
# Date of Expiry
#
# Permanent
# Address
#
# Present Address
#
#
#
# Tap to Zoom
#
#
#
# Driving License
#
# JANAM A PATEL
#
# GJ04 20220007060
# LMV,MCWG
#
# 2022-06-04
# 2003-10-05
#
# AJAY K PATEL
#
# 2043-10-04
#
# DHAJAGARAWALI SHERI KANBIWAD,
# OPP LEUVA PATEL WADI BHAVNAGAR (M
# CORP. + OG), Bhavnagar,GJ, 364001
#
# DHAJAGARAWALI SHERI KANBIWAD,
# OPP LEUVA PATEL WADI BHAVNAGAR (M
# CORP. + OG), Bhavnagar,GJ, 364001
#
#
#
# erified
#
# by DigiLocker

# %%
# popler utils is useful for pdf rendering tool
# !sudo apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.

# %%
#pdf2image library is for converting single page into image
# !pip install pdf2image

# %%
import io
from pdf2image import convert_from_path

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-83f02d10-fadc-4937-84d1-9784a5c0b1ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-83f02d10-fadc-4937-84d1-9784a5c0b1ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img1 = convert_from_path('SD fee 22-23.pdf',)
text_data = ''
#using for loop appending the text of pdf in a single variable
for page in img1:
  text = pytesseract.image_to_string(page)
  text_data += text

print(text_data)
# Out:
# Kelavanidham
#
# 6/22/22, 3:59 PM
#
# ORIGINAL
#
# Registration ID : SDH210331
# Name : JANAM AJAY PATEL
#
# Security Deposit (Refundable)(1000)
# IACCOMODATION(20000)
#
# Payment By
# UPI
# Total Amount in Words : twenty six thousands
#
#
#
#
#
# : Student / Parents Signature oe
#
# 9 BERR
#
# 7, Aeiléd asa, Yeu). doi as, wueraie-3c2vea
# " ge 2y. oi. : J/zocex/eeiaie | PAN : AAPTS3354N | GST : 24AAPTS3354N1ZU
#
# Email : info.sardardham@gmail.com * Website : www.sardardham.org
#
#
#
#
#
#
#
#
#
#
# [Address : OPP LEUVA PATEL WADI, DHAJAGARA STREET, KANBIVAD, BHAVNAGAR
#
# HSN/SAC
# |ACCOMODATION(5000) 9963
#
#
#
#
#
# Receipt Number : 1043
# Receipt Date : 22-06-2022
#
# Academic Year : 2022-2023
# Valid Up To :31-05-2023
#
# [Amount(Rupees)
#
# 1000.00
# 20000.00
#
# 5000.00
# 26000.00
# Amount
# 26000.00
#
#
#
#
#
#
#
#
# 9963
#
#
#
#
# Total Amount
#
#
#
#
#
#
#
#
#
#
# Authorised Signature
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
